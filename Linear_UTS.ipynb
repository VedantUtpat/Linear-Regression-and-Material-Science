# %%
from sklearn import svm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model

from sklearn.neighbors import KNeighborsClassifier

# %%
data= pd.read_csv('AllProp1.csv')
data.head()
# Out:
#       Al    Cu   Si    Fe    Mn     zn     Ti     Mg  Residuals  (UTS)  \
# 0  88.25   7.0  2.0  0.60  0.30  0.125  0.125  0.050       0.25    190
# 1  83.40  10.0  4.0  1.25  0.00  1.250  0.000  0.125       0.00    210
# 2  88.65   3.5  6.0  0.50  0.25  0.500  0.125  0.050       0.25    190
# 3  87.80   1.5  8.0  0.50  0.40  0.075  0.125  0.400       0.25    200
# 4  85.40   3.5  9.0  0.50  0.25  0.500  0.125  0.275       0.25    230
#
#    Tensile Strength: Yield (Proof)  Brinell Hardness  Fatigue Strength
# 0                              130                85                93
# 1                              170                56               110
# 2                              110                78                77
# 3                              120                60                80
# 4                              130                90                96

# %%
X = data.drop(columns=['(UTS)','Tensile Strength: Yield (Proof)','Brinell Hardness','Fatigue Strength'])
y = data[['(UTS)']]

# %%
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=109) # 70% training and 30% test

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)
y_predi = regr.predict(X)

# %%
test_data = np.array([88.25,7,2,0.6,0.3,0.125,0.125,0.05,0.25])
print( regr.predict(test_data.reshape(1,9)))
# Out:
# [[194.05424323]]
# C:\Users\Vedant\.conda\envs\ANN\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
test_data = np.array([88.25,7,2,0.6,0.3,0.125,0.125,0.05,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([83.4,10,4,1.25,0,1.25,0,0.125,0])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([88.65,3.5,6,0.5,0.25,0.5,0.125,0.05,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([87.8,1.5,8,0.5,0.4,0.075,0.125,0.4,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([85.4,3.5,9,0.5,0.25,0.5,0.125,0.275,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([91.7,0.125,7,0.3,0.175,0.175,0.125,0.325,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([87.85,0.3,9.5,1,0.175,0.25,0.075,0.5,0.125])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([84.55,3.5,8.5,1,0.25,1.5,0.175,0.05,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([81.9,3.75,11.25,0.65,0.25,1.5,0.175,0.1,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([77.25,0.6,19,0.75,0.4,0.25,0.15,1,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([93.1,0.3,5.25,0.4,0.25,0.25,0.125,0.05,0.175])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([94.75,0.075,0.5,0.25,0.175,0.075,0.125,4,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([93.5,0.05,0.15,0.2,0.15,1.8,0.1,4,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([95.1,0.1,5.25,0.65,0.5,0.05,0,3.25,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([91.8,0.5,0.075,0.25,0.025,6.5,0.125,0.7,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.35,0.125,0.15,0.25,0.05,5.75,0.2,0.575,0.1])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([91.5,0.05,0.075,0.075,0.05,7,0.15,0.9,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.2,0.1,7,0.1,0.05,0.05,0.1,0.35,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([88.2,0.3,9.5,0.65,0.175,0.25,0.075,0.5,0.125])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([82.9,3.75,11.25,0.65,0.25,0.5,0,0.05,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([85.95,0.5,12,0.65,0.175,0.25,0,0.05,0.125])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.4,0.05,0.1,0.1,0.175,0,0.125,7,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([93.7,0.075,5.25,0.4,0.175,0.175,0.125,0.05,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([88.35,4.5,5.5,0.5,0.25,0.5,0.125,0.05,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([89.75,0.5,7.5,0.6,0.25,0.5,0.1,0.55,0.1])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([89.6,0.1,8.5,0.75,0.05,0.075,0,0.3,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([84.1,2.5,10.5,0.065,0.25,1.5,0,0.25,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([77.05,4.5,17,0.65,0.05,0.05,0.1,0.55,0.1])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([85.6,0.5,12,1,0.175,0.25,0,0.05,0.125])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.85,0.175,1.8,0.3,0.4,0.175,0.125,4,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([95.05,0.075,0.175,0.25,0.175,0.075,0.125,4,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([90.3,0.125,0.175,0.9,0.175,0.075,0,8,0.125])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.55,0.025,0.075,0.075,0.175,0,0.125,6.85,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.05,0,0.1,0.4,0.5,4.25,0.125,2.1,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([90,0.7,0.125,0.55,0.3,0,0.125,0.35,0.125])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.2,0.05,0.075,0.075,0.05,6.5,0.15,0.7,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([84.9,3.5,8.5,0.65,0.25,1.5,0,0.05,0.25])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([77.45,4.5,17,0.25,0.05,0.05,0.1,0.55,0.1])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([76.15,4.5,17,0.65,0.25,0.75,0.05,0.55,0.1])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.55,0.05,0.075,0.075,0.025,0,0.175,7,0.075])
print( regr.predict(test_data.reshape(1,9)))

test_data = np.array([92.55,0.3,5.25,1,0.175,0,0,0.05,0.125])
print( regr.predict(test_data.reshape(1,9)))
# Out:
# [[194.05424323]]
# [[204.14293316]]
# [[225.78165164]]
# [[264.54428355]]
# [[259.1218143]]
# [[174.14085902]]
# [[278.09365879]]
# [[316.8976175]]
# [[312.91528422]]
# [[402.27021338]]
# [[191.97263168]]
# [[193.28786656]]
# [[231.28295621]]
# [[242.58765325]]
# [[271.32794387]]
# [[258.84845667]]
# [[278.21383889]]
# [[144.57697523]]
# [[248.35890357]]
# [[293.62992847]]
# [[264.18024291]]
# [[245.4746375]]
# [[159.81401383]]
# [[217.41233229]]
# [[232.02810054]]
# [[222.15949861]]
# [[272.77948414]]
# [[285.54479946]]
# [[293.91499813]]
# [[232.27720493]]
# [[190.48995083]]
# [[357.3718977]]
# [[240.28813146]]
# [[301.73395756]]
# [[215.46463876]]
# [[260.00746898]]
# [[295.61836619]]
# [[251.56222207]]
# [[323.83615573]]
# [[228.40337749]]
# [[227.12087394]]
# C:\Users\Vedant\.conda\envs\ANN\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...

# %%
from sklearn import metrics
print('Mean Absolute Percentage Error:', metrics.mean_absolute_percentage_error(y, y_predi))
print('Mean Absolute Percentage Error:', metrics.mean_absolute_percentage_error(y_test, y_pred))
# Out:
# Mean Absolute Percentage Error: 0.12897539980382097
# Mean Absolute Percentage Error: 0.20515245513578487
